# %% [markdown]
# **Задача 1:**
#
# На складе лежат разные фрукты в разном количестве.
# Нужно написать функцию, которая на вход принимает любое количество названий фруктов и их количество, а возвращает общее количество фруктов на складе, при помощи использования kwargs

# %%
def fruits(**kwargs):
    fr = []
    for k, v in kwargs.items():
        fr.append(v)
    s = sum(fr)
    return(s)
    
f = fruits(a = 9, o = 2, b = 15)
print(f'Общее количество фруктов на складе - {f}')
# Out:
# Общее количество фруктов на складе - 26

# %% [markdown]
# **Задача 2:**
#
# Дан список с затратами на рекламу. Но в данных есть ошибки, некоторые затраты имеют отрицательную величину. Удалите такие значения из списка и посчитайте суммарные затраты
#
# ```[100, 125, -90, 345, 655, -1, 0, 200]```
#
# Используйте list comprehensions

# %%
exp = [100, 125, -90, 345, 655, -1, 0, 200]
exp_pos = [i for i in cost if i>0]
total_exp = sum(exp_pos)
print(exp_pos)
print(f'Суммарные затраты составляют {total_exp}')

# exp_total = sum(i for i in cost if i>0) - сразу подсчет суммы, без вывода списка положительных затрат
# print(exp_total)
# Out:
# [100, 125, 345, 655, 200]
# Суммарные затраты составляют 1425

# %% [markdown]
# **Задача 3:**
#
# Даны два списка.
#
# Дата покупки
# ```['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']```
#
# Суммы покупок по датам
# ```[1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]```

# %%
day = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
amount = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]

# %% [markdown]
# ***4.1:*** Найдите, какая выручка у компании в ноябре
# Используйте list comprehensions

# %%
rev_nov = sum(amount[i] for i in range(len(amount)) if day[i].split('-')[1] == '11')
print(f'Выручка компании в ноябре составила {rev_nov}')
# Out:
# Выручка компании в ноябре составила 25098

# %% [markdown]
# ***4.2:***
# Найдите выручку компании в зависимости от месяца.
# Для этого напишите функцию, которая на вход принимает список с датами и список с выручкой, а на выходе словарь, где ключи - это месяцы, а значения - это выручка.
# Используйте аннотирование типов.

# %%
def revenue(day: list, amount: list) -> dict: 
    month = {}
    for i in range(len(day)):
        if day[i].split('-')[1] not in month:
            month[day[i].split('-')[1]] = amount[i]
        else:
            month[day[i].split('-')[1]] += amount[i]
    return month
print(f'Выручка компании по месяцам составляет: {revenue(day, amount)}')
# Out:
# Выручка компании по месяцам составляет: {'09': 25647, '12': 45452, '10': 28645, '11': 25098}
